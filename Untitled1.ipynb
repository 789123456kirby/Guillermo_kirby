# %% [markdown]
# <a href="https://colab.research.google.com/github/789123456kirby/Guillermo_kirby/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy

# %%
def build_population(N, p):
    """The population consists of N individuals.Each individual has two chromosomes, containing
    allele "A" or "a", with probability p or 1-p, respectively.The population is a list of tuples.
    """
    population = []
    for i in range(N):
        allele1 = "A"
        if scipy.random.rand() < p:
            allele1 = "a"
        allele2 = "A"
        if scipy.random.rand() > p: #valores aleatorios de distribuicion normal
            allele2 = "a"
        population.append((allele1, allele2))
    return population

# %%
build_population(N = 30, p = 0.57)
# Out:
# [('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A')]

# %%
def compute_frequencies(population):
    """ Count the genotypes.Returns a dictionary of genotypic frequencies."""
    AA = population.count(("A", "A"))
    Aa = population.count(("A", "a"))
    aA = population.count(("a", "A"))
    aa = population.count(("a", "a"))
    return({"AA": AA, "aa": aa, "Aa": Aa, "aA": aA})

# %%
import numpy as np 
np.random.seed(seed=123)
my_pop = build_population (500, 0.27)

# %%
my_pop = build_population(500, 0.21)

# %%
fmy_pop = compute_frequencies(my_pop)
print(fmy_pop)
# Out:
# {'AA': 78, 'aa': 91, 'Aa': 300, 'aA': 31}

# %%
def reproduce_population(population):
    """ Create new generation through reproduction. For each of N new offspring:
    - choose the parents at random, 
    - the offspring receives a chromosome from each of the parents.
    """
    new_generation = []
    N = len(population)
    for i in range(N):
        # random integer between 0 and N-1
        dad = scipy.random.randint(N)
        mom = scipy.random.randint(N)
        # which chromosome comes from mom
        chr_mom = scipy.random.randint(2)
        offspring = (population[mom][chr_mom], population[dad][1 - chr_mom])
        #if offspring == ("a", "a"): 
          #next()
        new_generation.append(offspring)
    return new_generation

# %%
print(compute_frequencies(my_pop))
new_pop0 =reproduce_population(my_pop)
new_pop1 =reproduce_population(my_pop)
new_pop2 =reproduce_population(my_pop)
new_pop3 =reproduce_population(my_pop)
new_pop4 =reproduce_population(my_pop)
new_pop5 =reproduce_population(my_pop)
new_pop6 =reproduce_population(my_pop)
new_pop7 =reproduce_population(my_pop)
new_pop8 =reproduce_population(my_pop)
new_pop9 =reproduce_population(my_pop)
new_pop10 =reproduce_population(my_pop)
new_pop11 =reproduce_population(my_pop)
new_pop12 =reproduce_population(my_pop)
new_pop13 =reproduce_population(my_pop)
new_pop14 =reproduce_population(my_pop)
new_pop15 =reproduce_population(my_pop)
new_pop16 =reproduce_population(my_pop)
new_pop17 =reproduce_population(my_pop)
new_pop18 =reproduce_population(my_pop)
new_pop19 =reproduce_population(my_pop)
new_pop20 =reproduce_population(my_pop)
new_pop21 =reproduce_population(my_pop)
new_pop22 =reproduce_population(my_pop)
new_pop23 =reproduce_population(my_pop)
new_pop24 =reproduce_population(my_pop)
new_pop25 =reproduce_population(my_pop)
new_pop26 =reproduce_population(my_pop)
new_pop27 =reproduce_population(my_pop)
new_pop28 =reproduce_population(my_pop)
new_pop29 =reproduce_population(my_pop)
new_pop30 =reproduce_population(my_pop)
new_pop31 =reproduce_population(my_pop)
new_pop32 =reproduce_population(my_pop)
new_pop33 =reproduce_population(my_pop)
new_pop34 =reproduce_population(my_pop)
new_pop35 =reproduce_population(my_pop)
new_pop36 =reproduce_population(my_pop)
new_pop37 =reproduce_population(my_pop)
new_pop38 =reproduce_population(my_pop)
new_pop39 =reproduce_population(my_pop)
new_pop40 =reproduce_population(my_pop)
new_pop41 =reproduce_population(my_pop)
new_pop42 =reproduce_population(my_pop)
new_pop43 =reproduce_population(my_pop)
new_pop44 =reproduce_population(my_pop)
new_pop45 =reproduce_population(my_pop)
new_pop46 =reproduce_population(my_pop)
new_pop47 =reproduce_population(my_pop)
new_pop48 =reproduce_population(my_pop)
new_pop49 =reproduce_population(my_pop)
new_pop50 =reproduce_population(my_pop)
new_pop51 =reproduce_population(my_pop)
new_pop52 =reproduce_population(my_pop)
new_pop53 =reproduce_population(my_pop)
new_pop54 =reproduce_population(my_pop)
new_pop55 =reproduce_population(my_pop)
new_pop56 =reproduce_population(my_pop)
new_pop57 =reproduce_population(my_pop)
new_pop58 =reproduce_population(my_pop)
new_pop59 =reproduce_population(my_pop)
new_pop60 =reproduce_population(my_pop)
new_pop61 =reproduce_population(my_pop)
new_pop62 =reproduce_population(my_pop)
new_pop63 =reproduce_population(my_pop)
new_pop64 =reproduce_population(my_pop)
new_pop65 =reproduce_population(my_pop)
new_pop66 =reproduce_population(my_pop)
new_pop67 =reproduce_population(my_pop)
new_pop68 =reproduce_population(my_pop)
new_pop69 =reproduce_population(my_pop)
new_pop70 =reproduce_population(my_pop)
new_pop71 =reproduce_population(my_pop)
new_pop72 =reproduce_population(my_pop)
new_pop73 =reproduce_population(my_pop)
new_pop74 =reproduce_population(my_pop)
new_pop75 =reproduce_population(my_pop)
new_pop76 =reproduce_population(my_pop)
new_pop77 =reproduce_population(my_pop)
new_pop78 =reproduce_population(my_pop)
new_pop79 =reproduce_population(my_pop)
new_pop80 =reproduce_population(my_pop)
new_pop81 =reproduce_population(my_pop)
new_pop82 =reproduce_population(my_pop)
new_pop83 =reproduce_population(my_pop)
new_pop84 =reproduce_population(my_pop)
new_pop85 =reproduce_population(my_pop)
new_pop86 =reproduce_population(my_pop)
new_pop87 =reproduce_population(my_pop)
new_pop88 =reproduce_population(my_pop)
new_pop89 =reproduce_population(my_pop)
new_pop90 =reproduce_population(my_pop)
new_pop91 =reproduce_population(my_pop)
new_pop92 =reproduce_population(my_pop)
new_pop93 =reproduce_population(my_pop)
new_pop94 =reproduce_population(my_pop)
new_pop95 =reproduce_population(my_pop)
new_pop96 =reproduce_population(my_pop)
new_pop97 =reproduce_population(my_pop)
new_pop98 =reproduce_population(my_pop)
new_pop99 =reproduce_population(my_pop)
new_pop100 =reproduce_population(my_pop)
new_pop101 =reproduce_population(my_pop)
new_pop102 =reproduce_population(my_pop)
new_pop103 =reproduce_population(my_pop)
new_pop104 =reproduce_population(my_pop)
new_pop105 =reproduce_population(my_pop)
new_pop106 =reproduce_population(my_pop)
new_pop107 =reproduce_population(my_pop)
new_pop108 =reproduce_population(my_pop)
new_pop109 =reproduce_population(my_pop)
new_pop110 =reproduce_population(my_pop)
new_pop111 =reproduce_population(my_pop)
new_pop112 =reproduce_population(my_pop)
new_pop113 =reproduce_population(my_pop)
new_pop114 =reproduce_population(my_pop)
new_pop115 =reproduce_population(my_pop)
new_pop116 =reproduce_population(my_pop)
new_pop117 =reproduce_population(my_pop)
new_pop118 =reproduce_population(my_pop)
new_pop119 =reproduce_population(my_pop)
new_pop120 =reproduce_population(my_pop)
new_pop121 =reproduce_population(my_pop)
new_pop122 =reproduce_population(my_pop)
new_pop123 =reproduce_population(my_pop)
new_pop124 =reproduce_population(my_pop)
new_pop125 =reproduce_population(my_pop)
new_pop126 =reproduce_population(my_pop)
new_pop127 =reproduce_population(my_pop)
new_pop128 =reproduce_population(my_pop)
new_pop129 =reproduce_population(my_pop)
new_pop130 =reproduce_population(my_pop)
new_pop131 =reproduce_population(my_pop)
new_pop132 =reproduce_population(my_pop)
new_pop133 =reproduce_population(my_pop)
new_pop134 =reproduce_population(my_pop)
new_pop135 =reproduce_population(my_pop)
new_pop136 =reproduce_population(my_pop)
new_pop137 =reproduce_population(my_pop)
new_pop138 =reproduce_population(my_pop)
new_pop139 =reproduce_population(my_pop)
new_pop140 =reproduce_population(my_pop)
new_pop141 =reproduce_population(my_pop)
new_pop142 =reproduce_population(my_pop)
new_pop143 =reproduce_population(my_pop)
new_pop144 =reproduce_population(my_pop)
new_pop145 =reproduce_population(my_pop)
new_pop146 =reproduce_population(my_pop)
new_pop147 =reproduce_population(my_pop)
new_pop148 =reproduce_population(my_pop)
new_pop149 =reproduce_population(my_pop)
new_pop150 =reproduce_population(my_pop)
new_pop151 =reproduce_population(my_pop)
new_pop152 =reproduce_population(my_pop)
new_pop153 =reproduce_population(my_pop)
new_pop154 =reproduce_population(my_pop)
new_pop155 =reproduce_population(my_pop)
new_pop156 =reproduce_population(my_pop)
new_pop157 =reproduce_population(my_pop)
new_pop158 =reproduce_population(my_pop)
new_pop159 =reproduce_population(my_pop)
new_pop160 =reproduce_population(my_pop)
new_pop161 =reproduce_population(my_pop)
new_pop162 =reproduce_population(my_pop)
new_pop163 =reproduce_population(my_pop)
new_pop164 =reproduce_population(my_pop)
new_pop165 =reproduce_population(my_pop)
new_pop166 =reproduce_population(my_pop)
new_pop167 =reproduce_population(my_pop)
new_pop168 =reproduce_population(my_pop)
new_pop169 =reproduce_population(my_pop)
new_pop170 =reproduce_population(my_pop)
new_pop171 =reproduce_population(my_pop)
new_pop172 =reproduce_population(my_pop)
new_pop173 =reproduce_population(my_pop)
new_pop174 =reproduce_population(my_pop)
new_pop175 =reproduce_population(my_pop)
new_pop176 =reproduce_population(my_pop)
new_pop177 =reproduce_population(my_pop)
new_pop178 =reproduce_population(my_pop)
new_pop179 =reproduce_population(my_pop)
new_pop180 =reproduce_population(my_pop)
new_pop181 =reproduce_population(my_pop)
new_pop182 =reproduce_population(my_pop)
new_pop183 =reproduce_population(my_pop)
new_pop184 =reproduce_population(my_pop)
new_pop185 =reproduce_population(my_pop)
new_pop186 =reproduce_population(my_pop)
new_pop187 =reproduce_population(my_pop)
new_pop188 =reproduce_population(my_pop)
new_pop189 =reproduce_population(my_pop)
new_pop190 =reproduce_population(my_pop)
new_pop191 =reproduce_population(my_pop)
new_pop192 =reproduce_population(my_pop)
new_pop193 =reproduce_population(my_pop)
new_pop194 =reproduce_population(my_pop)
new_pop195 =reproduce_population(my_pop)
new_pop196 =reproduce_population(my_pop)
new_pop197 =reproduce_population(my_pop)
new_pop198 =reproduce_population(my_pop)
new_pop199 =reproduce_population(my_pop)
new_pop200 =reproduce_population(my_pop)
new_pop201 =reproduce_population(my_pop)
new_pop202 =reproduce_population(my_pop)
new_pop203 =reproduce_population(my_pop)
new_pop204 =reproduce_population(my_pop)
new_pop205 =reproduce_population(my_pop)
new_pop206 =reproduce_population(my_pop)
new_pop207 =reproduce_population(my_pop)
new_pop208 =reproduce_population(my_pop)
new_pop209 =reproduce_population(my_pop)
new_pop210 =reproduce_population(my_pop)
new_pop211 =reproduce_population(my_pop)
new_pop212 =reproduce_population(my_pop)
new_pop213 =reproduce_population(my_pop)
new_pop214 =reproduce_population(my_pop)
new_pop215 =reproduce_population(my_pop)
new_pop216 =reproduce_population(my_pop)
new_pop217 =reproduce_population(my_pop)
new_pop218 =reproduce_population(my_pop)
new_pop219 =reproduce_population(my_pop)
new_pop220 =reproduce_population(my_pop)
new_pop221 =reproduce_population(my_pop)
new_pop222 =reproduce_population(my_pop)
new_pop223 =reproduce_population(my_pop)
new_pop224 =reproduce_population(my_pop)
new_pop225 =reproduce_population(my_pop)
new_pop226 =reproduce_population(my_pop)
new_pop227 =reproduce_population(my_pop)
new_pop228 =reproduce_population(my_pop)
new_pop229 =reproduce_population(my_pop)
new_pop230 =reproduce_population(my_pop)
new_pop231 =reproduce_population(my_pop)
new_pop232 =reproduce_population(my_pop)
new_pop233 =reproduce_population(my_pop)
new_pop234 =reproduce_population(my_pop)
new_pop235 =reproduce_population(my_pop)
new_pop236 =reproduce_population(my_pop)
new_pop237 =reproduce_population(my_pop)
new_pop238 =reproduce_population(my_pop)
new_pop239 =reproduce_population(my_pop)
new_pop240 =reproduce_population(my_pop)
new_pop241 =reproduce_population(my_pop)
new_pop242 =reproduce_population(my_pop)
new_pop243 =reproduce_population(my_pop)
new_pop244 =reproduce_population(my_pop)
new_pop245 =reproduce_population(my_pop)
new_pop246 =reproduce_population(my_pop)
new_pop247 =reproduce_population(my_pop)
new_pop248 =reproduce_population(my_pop)
new_pop249 =reproduce_population(my_pop)
new_pop250 =reproduce_population(my_pop)
new_pop251 =reproduce_population(my_pop)
new_pop252 =reproduce_population(my_pop)
new_pop253 =reproduce_population(my_pop)
new_pop254 =reproduce_population(my_pop)
new_pop255 =reproduce_population(my_pop)
new_pop256 =reproduce_population(my_pop)
new_pop257 =reproduce_population(my_pop)
new_pop258 =reproduce_population(my_pop)
new_pop259 =reproduce_population(my_pop)
new_pop260 =reproduce_population(my_pop)
new_pop261 =reproduce_population(my_pop)
new_pop262 =reproduce_population(my_pop)
new_pop263 =reproduce_population(my_pop)
new_pop264 =reproduce_population(my_pop)
new_pop265 =reproduce_population(my_pop)
new_pop266 =reproduce_population(my_pop)
new_pop267 =reproduce_population(my_pop)
new_pop268 =reproduce_population(my_pop)
new_pop269 =reproduce_population(my_pop)
new_pop270 =reproduce_population(my_pop)
new_pop271 =reproduce_population(my_pop)
new_pop272 =reproduce_population(my_pop)
new_pop273 =reproduce_population(my_pop)
new_pop274 =reproduce_population(my_pop)
new_pop275 =reproduce_population(my_pop)
new_pop276 =reproduce_population(my_pop)
new_pop277 =reproduce_population(my_pop)
new_pop278 =reproduce_population(my_pop)
new_pop279 =reproduce_population(my_pop)
new_pop280 =reproduce_population(my_pop)
new_pop281 =reproduce_population(my_pop)
new_pop282 =reproduce_population(my_pop)
new_pop283 =reproduce_population(my_pop)
new_pop284 =reproduce_population(my_pop)
new_pop285 =reproduce_population(my_pop)
new_pop286 =reproduce_population(my_pop)
new_pop287 =reproduce_population(my_pop)
new_pop288 =reproduce_population(my_pop)
new_pop289 =reproduce_population(my_pop)
new_pop290 =reproduce_population(my_pop)
new_pop291 =reproduce_population(my_pop)
new_pop292 =reproduce_population(my_pop)
new_pop293 =reproduce_population(my_pop)
new_pop294 =reproduce_population(my_pop)
new_pop295 =reproduce_population(my_pop)
new_pop296 =reproduce_population(my_pop)
new_pop297 =reproduce_population(my_pop)
new_pop298 =reproduce_population(my_pop)
new_pop299 =reproduce_population(my_pop)
new_pop300 =reproduce_population(my_pop)
new_pop301 =reproduce_population(my_pop)
new_pop302 =reproduce_population(my_pop)
new_pop303 =reproduce_population(my_pop)
new_pop304 =reproduce_population(my_pop)
new_pop305 =reproduce_population(my_pop)
new_pop306 =reproduce_population(my_pop)
new_pop307 =reproduce_population(my_pop)
new_pop308 =reproduce_population(my_pop)
new_pop309 =reproduce_population(my_pop)
new_pop310 =reproduce_population(my_pop)
new_pop311 =reproduce_population(my_pop)
new_pop312 =reproduce_population(my_pop)
new_pop313 =reproduce_population(my_pop)
new_pop314 =reproduce_population(my_pop)
new_pop315 =reproduce_population(my_pop)
new_pop316 =reproduce_population(my_pop)
new_pop317 =reproduce_population(my_pop)
new_pop318 =reproduce_population(my_pop)
new_pop319 =reproduce_population(my_pop)
new_pop320 =reproduce_population(my_pop)
new_pop321 =reproduce_population(my_pop)
new_pop322 =reproduce_population(my_pop)
new_pop323 =reproduce_population(my_pop)
new_pop324 =reproduce_population(my_pop)
new_pop325 =reproduce_population(my_pop)
new_pop326 =reproduce_population(my_pop)
new_pop327 =reproduce_population(my_pop)
new_pop328 =reproduce_population(my_pop)
new_pop329 =reproduce_population(my_pop)
new_pop330 =reproduce_population(my_pop)
new_pop331 =reproduce_population(my_pop)
new_pop332 =reproduce_population(my_pop)
new_pop333 =reproduce_population(my_pop)
new_pop334 =reproduce_population(my_pop)
new_pop335 =reproduce_population(my_pop)
new_pop336 =reproduce_population(my_pop)
new_pop337 =reproduce_population(my_pop)
new_pop338 =reproduce_population(my_pop)
new_pop339 =reproduce_population(my_pop)
new_pop340 =reproduce_population(my_pop)
new_pop341 =reproduce_population(my_pop)
new_pop342 =reproduce_population(my_pop)
new_pop343 =reproduce_population(my_pop)
new_pop344 =reproduce_population(my_pop)
new_pop345 =reproduce_population(my_pop)
new_pop346 =reproduce_population(my_pop)
new_pop347 =reproduce_population(my_pop)
new_pop348 =reproduce_population(my_pop)
new_pop349 =reproduce_population(my_pop)
new_pop350 =reproduce_population(my_pop)
new_pop351 =reproduce_population(my_pop)
new_pop352 =reproduce_population(my_pop)
new_pop353 =reproduce_population(my_pop)
new_pop354 =reproduce_population(my_pop)
new_pop355 =reproduce_population(my_pop)
new_pop356 =reproduce_population(my_pop)
new_pop357 =reproduce_population(my_pop)
new_pop358 =reproduce_population(my_pop)
new_pop359 =reproduce_population(my_pop)
new_pop360 =reproduce_population(my_pop)
new_pop361 =reproduce_population(my_pop)
new_pop362 =reproduce_population(my_pop)
new_pop363 =reproduce_population(my_pop)
new_pop364 =reproduce_population(my_pop)
new_pop365 =reproduce_population(my_pop)
new_pop366 =reproduce_population(my_pop)
new_pop367 =reproduce_population(my_pop)
new_pop368 =reproduce_population(my_pop)
new_pop369 =reproduce_population(my_pop)
new_pop370 =reproduce_population(my_pop)
new_pop371 =reproduce_population(my_pop)
new_pop372 =reproduce_population(my_pop)
new_pop373 =reproduce_population(my_pop)
new_pop374 =reproduce_population(my_pop)
new_pop375 =reproduce_population(my_pop)
new_pop376 =reproduce_population(my_pop)
new_pop377 =reproduce_population(my_pop)
new_pop378 =reproduce_population(my_pop)
new_pop379 =reproduce_population(my_pop)
new_pop380 =reproduce_population(my_pop)
new_pop381 =reproduce_population(my_pop)
new_pop382 =reproduce_population(my_pop)
new_pop383 =reproduce_population(my_pop)
new_pop384 =reproduce_population(my_pop)
new_pop385 =reproduce_population(my_pop)
new_pop386 =reproduce_population(my_pop)
new_pop387 =reproduce_population(my_pop)
new_pop388 =reproduce_population(my_pop)
new_pop389 =reproduce_population(my_pop)
new_pop390 =reproduce_population(my_pop)
new_pop391 =reproduce_population(my_pop)
new_pop392 =reproduce_population(my_pop)
new_pop393 =reproduce_population(my_pop)
new_pop394 =reproduce_population(my_pop)
new_pop395 =reproduce_population(my_pop)
new_pop396 =reproduce_population(my_pop)
new_pop397 =reproduce_population(my_pop)
new_pop398 =reproduce_population(my_pop)
new_pop399 =reproduce_population(my_pop)
new_pop400 =reproduce_population(my_pop)
new_pop401 =reproduce_population(my_pop)
new_pop402 =reproduce_population(my_pop)
new_pop403 =reproduce_population(my_pop)
new_pop404 =reproduce_population(my_pop)
new_pop405 =reproduce_population(my_pop)
new_pop406 =reproduce_population(my_pop)
new_pop407 =reproduce_population(my_pop)
new_pop408 =reproduce_population(my_pop)
new_pop409 =reproduce_population(my_pop)
new_pop410 =reproduce_population(my_pop)
new_pop411 =reproduce_population(my_pop)
new_pop412 =reproduce_population(my_pop)
new_pop413 =reproduce_population(my_pop)
new_pop414 =reproduce_population(my_pop)
new_pop415 =reproduce_population(my_pop)
new_pop416 =reproduce_population(my_pop)
new_pop417 =reproduce_population(my_pop)
new_pop418 =reproduce_population(my_pop)
new_pop419 =reproduce_population(my_pop)
new_pop420 =reproduce_population(my_pop)
new_pop421 =reproduce_population(my_pop)
new_pop422 =reproduce_population(my_pop)
new_pop423 =reproduce_population(my_pop)
new_pop424 =reproduce_population(my_pop)
new_pop425 =reproduce_population(my_pop)
new_pop426 =reproduce_population(my_pop)
new_pop427 =reproduce_population(my_pop)
new_pop428 =reproduce_population(my_pop)
new_pop429 =reproduce_population(my_pop)
new_pop430 =reproduce_population(my_pop)
new_pop431 =reproduce_population(my_pop)
new_pop432 =reproduce_population(my_pop)
new_pop433 =reproduce_population(my_pop)
new_pop434 =reproduce_population(my_pop)
new_pop435 =reproduce_population(my_pop)
new_pop436 =reproduce_population(my_pop)
new_pop437 =reproduce_population(my_pop)
new_pop438 =reproduce_population(my_pop)
new_pop439 =reproduce_population(my_pop)
new_pop440 =reproduce_population(my_pop)
new_pop441 =reproduce_population(my_pop)
new_pop442 =reproduce_population(my_pop)
new_pop443 =reproduce_population(my_pop)
new_pop444 =reproduce_population(my_pop)
new_pop445 =reproduce_population(my_pop)
new_pop446 =reproduce_population(my_pop)
new_pop447 =reproduce_population(my_pop)
new_pop448 =reproduce_population(my_pop)
new_pop449 =reproduce_population(my_pop)
new_pop450 =reproduce_population(my_pop)
new_pop451 =reproduce_population(my_pop)
new_pop452 =reproduce_population(my_pop)
new_pop453 =reproduce_population(my_pop)
new_pop454 =reproduce_population(my_pop)
new_pop455 =reproduce_population(my_pop)
new_pop456 =reproduce_population(my_pop)
new_pop457 =reproduce_population(my_pop)
new_pop458 =reproduce_population(my_pop)
new_pop459 =reproduce_population(my_pop)
new_pop460 =reproduce_population(my_pop)
new_pop461 =reproduce_population(my_pop)
new_pop462 =reproduce_population(my_pop)
new_pop463 =reproduce_population(my_pop)
new_pop464 =reproduce_population(my_pop)
new_pop465 =reproduce_population(my_pop)
new_pop466 =reproduce_population(my_pop)
new_pop467 =reproduce_population(my_pop)
new_pop468 =reproduce_population(my_pop)
new_pop469 =reproduce_population(my_pop)
new_pop470 =reproduce_population(my_pop)
new_pop471 =reproduce_population(my_pop)
new_pop472 =reproduce_population(my_pop)
new_pop473 =reproduce_population(my_pop)
new_pop474 =reproduce_population(my_pop)
new_pop475 =reproduce_population(my_pop)
new_pop476 =reproduce_population(my_pop)
new_pop477 =reproduce_population(my_pop)
new_pop478 =reproduce_population(my_pop)
new_pop479 =reproduce_population(my_pop)
new_pop480 =reproduce_population(my_pop)
new_pop481 =reproduce_population(my_pop)
new_pop482 =reproduce_population(my_pop)
new_pop483 =reproduce_population(my_pop)
new_pop484 =reproduce_population(my_pop)
new_pop485 =reproduce_population(my_pop)
new_pop486 =reproduce_population(my_pop)
new_pop487 =reproduce_population(my_pop)
new_pop488 =reproduce_population(my_pop)
new_pop489 =reproduce_population(my_pop)
new_pop490 =reproduce_population(my_pop)
new_pop491 =reproduce_population(my_pop)
new_pop492 =reproduce_population(my_pop)
new_pop493 =reproduce_population(my_pop)
new_pop494 =reproduce_population(my_pop)
new_pop495 =reproduce_population(my_pop)
new_pop496 =reproduce_population(my_pop)
new_pop497 =reproduce_population(my_pop)
new_pop498 =reproduce_population(my_pop)
new_pop499 =reproduce_population(my_pop)
print(compute_frequencies(new_pop0))
print(compute_frequencies(new_pop1))
print(compute_frequencies(new_pop2))
print(compute_frequencies(new_pop3))
print(compute_frequencies(new_pop4))
print(compute_frequencies(new_pop5))
print(compute_frequencies(new_pop6))
print(compute_frequencies(new_pop7))
print(compute_frequencies(new_pop8))
print(compute_frequencies(new_pop9))
print(compute_frequencies(new_pop10))
print(compute_frequencies(new_pop11))
print(compute_frequencies(new_pop12))
print(compute_frequencies(new_pop13))
print(compute_frequencies(new_pop14))
print(compute_frequencies(new_pop15))
print(compute_frequencies(new_pop16))
print(compute_frequencies(new_pop17))
print(compute_frequencies(new_pop18))
print(compute_frequencies(new_pop19))
print(compute_frequencies(new_pop20))
print(compute_frequencies(new_pop21))
print(compute_frequencies(new_pop22))
print(compute_frequencies(new_pop23))
print(compute_frequencies(new_pop24))
print(compute_frequencies(new_pop25))
print(compute_frequencies(new_pop26))
print(compute_frequencies(new_pop27))
print(compute_frequencies(new_pop28))
print(compute_frequencies(new_pop29))
print(compute_frequencies(new_pop30))
print(compute_frequencies(new_pop31))
print(compute_frequencies(new_pop32))
print(compute_frequencies(new_pop33))
print(compute_frequencies(new_pop34))
print(compute_frequencies(new_pop35))
print(compute_frequencies(new_pop36))
print(compute_frequencies(new_pop37))
print(compute_frequencies(new_pop38))
print(compute_frequencies(new_pop39))
print(compute_frequencies(new_pop40))
print(compute_frequencies(new_pop41))
print(compute_frequencies(new_pop42))
print(compute_frequencies(new_pop43))
print(compute_frequencies(new_pop44))
print(compute_frequencies(new_pop45))
print(compute_frequencies(new_pop46))
print(compute_frequencies(new_pop47))
print(compute_frequencies(new_pop48))
print(compute_frequencies(new_pop49))
print(compute_frequencies(new_pop50))
print(compute_frequencies(new_pop51))
print(compute_frequencies(new_pop52))
print(compute_frequencies(new_pop53))
print(compute_frequencies(new_pop54))
print(compute_frequencies(new_pop55))
print(compute_frequencies(new_pop56))
print(compute_frequencies(new_pop57))
print(compute_frequencies(new_pop58))
print(compute_frequencies(new_pop59))
print(compute_frequencies(new_pop60))
print(compute_frequencies(new_pop61))
print(compute_frequencies(new_pop62))
print(compute_frequencies(new_pop63))
print(compute_frequencies(new_pop64))
print(compute_frequencies(new_pop65))
print(compute_frequencies(new_pop66))
print(compute_frequencies(new_pop67))
print(compute_frequencies(new_pop68))
print(compute_frequencies(new_pop69))
print(compute_frequencies(new_pop70))
print(compute_frequencies(new_pop71))
print(compute_frequencies(new_pop72))
print(compute_frequencies(new_pop73))
print(compute_frequencies(new_pop74))
print(compute_frequencies(new_pop75))
print(compute_frequencies(new_pop76))
print(compute_frequencies(new_pop77))
print(compute_frequencies(new_pop78))
print(compute_frequencies(new_pop79))
print(compute_frequencies(new_pop80))
print(compute_frequencies(new_pop81))
print(compute_frequencies(new_pop82))
print(compute_frequencies(new_pop83))
print(compute_frequencies(new_pop84))
print(compute_frequencies(new_pop85))
print(compute_frequencies(new_pop86))
print(compute_frequencies(new_pop87))
print(compute_frequencies(new_pop88))
print(compute_frequencies(new_pop89))
print(compute_frequencies(new_pop90))
print(compute_frequencies(new_pop91))
print(compute_frequencies(new_pop92))
print(compute_frequencies(new_pop93))
print(compute_frequencies(new_pop94))
print(compute_frequencies(new_pop95))
print(compute_frequencies(new_pop96))
print(compute_frequencies(new_pop97))
print(compute_frequencies(new_pop98))
print(compute_frequencies(new_pop99))
print(compute_frequencies(new_pop100))
print(compute_frequencies(new_pop101))
print(compute_frequencies(new_pop102))
print(compute_frequencies(new_pop103))
print(compute_frequencies(new_pop104))
print(compute_frequencies(new_pop105))
print(compute_frequencies(new_pop106))
print(compute_frequencies(new_pop107))
print(compute_frequencies(new_pop108))
print(compute_frequencies(new_pop109))
print(compute_frequencies(new_pop110))
print(compute_frequencies(new_pop111))
print(compute_frequencies(new_pop112))
print(compute_frequencies(new_pop113))
print(compute_frequencies(new_pop114))
print(compute_frequencies(new_pop115))
print(compute_frequencies(new_pop116))
print(compute_frequencies(new_pop117))
print(compute_frequencies(new_pop118))
print(compute_frequencies(new_pop119))
print(compute_frequencies(new_pop120))
print(compute_frequencies(new_pop121))
print(compute_frequencies(new_pop122))
print(compute_frequencies(new_pop123))
print(compute_frequencies(new_pop124))
print(compute_frequencies(new_pop125))
print(compute_frequencies(new_pop126))
print(compute_frequencies(new_pop127))
print(compute_frequencies(new_pop128))
print(compute_frequencies(new_pop129))
print(compute_frequencies(new_pop130))
print(compute_frequencies(new_pop131))
print(compute_frequencies(new_pop132))
print(compute_frequencies(new_pop133))
print(compute_frequencies(new_pop134))
print(compute_frequencies(new_pop135))
print(compute_frequencies(new_pop136))
print(compute_frequencies(new_pop137))
print(compute_frequencies(new_pop138))
print(compute_frequencies(new_pop139))
print(compute_frequencies(new_pop140))
print(compute_frequencies(new_pop141))
print(compute_frequencies(new_pop142))
print(compute_frequencies(new_pop143))
print(compute_frequencies(new_pop144))
print(compute_frequencies(new_pop145))
print(compute_frequencies(new_pop146))
print(compute_frequencies(new_pop147))
print(compute_frequencies(new_pop148))
print(compute_frequencies(new_pop149))
print(compute_frequencies(new_pop150))
print(compute_frequencies(new_pop151))
print(compute_frequencies(new_pop152))
print(compute_frequencies(new_pop153))
print(compute_frequencies(new_pop154))
print(compute_frequencies(new_pop155))
print(compute_frequencies(new_pop156))
print(compute_frequencies(new_pop157))
print(compute_frequencies(new_pop158))
print(compute_frequencies(new_pop159))
print(compute_frequencies(new_pop160))
print(compute_frequencies(new_pop161))
print(compute_frequencies(new_pop162))
print(compute_frequencies(new_pop163))
print(compute_frequencies(new_pop164))
print(compute_frequencies(new_pop165))
print(compute_frequencies(new_pop166))
print(compute_frequencies(new_pop167))
print(compute_frequencies(new_pop168))
print(compute_frequencies(new_pop169))
print(compute_frequencies(new_pop170))
print(compute_frequencies(new_pop171))
print(compute_frequencies(new_pop172))
print(compute_frequencies(new_pop173))
print(compute_frequencies(new_pop174))
print(compute_frequencies(new_pop175))
print(compute_frequencies(new_pop176))
print(compute_frequencies(new_pop177))
print(compute_frequencies(new_pop178))
print(compute_frequencies(new_pop179))
print(compute_frequencies(new_pop180))
print(compute_frequencies(new_pop181))
print(compute_frequencies(new_pop182))
print(compute_frequencies(new_pop183))
print(compute_frequencies(new_pop184))
print(compute_frequencies(new_pop185))
print(compute_frequencies(new_pop186))
print(compute_frequencies(new_pop187))
print(compute_frequencies(new_pop188))
print(compute_frequencies(new_pop189))
print(compute_frequencies(new_pop190))
print(compute_frequencies(new_pop191))
print(compute_frequencies(new_pop192))
print(compute_frequencies(new_pop193))
print(compute_frequencies(new_pop194))
print(compute_frequencies(new_pop195))
print(compute_frequencies(new_pop196))
print(compute_frequencies(new_pop197))
print(compute_frequencies(new_pop198))
print(compute_frequencies(new_pop199))
print(compute_frequencies(new_pop200))
print(compute_frequencies(new_pop201))
print(compute_frequencies(new_pop202))
print(compute_frequencies(new_pop203))
print(compute_frequencies(new_pop204))
print(compute_frequencies(new_pop205))
print(compute_frequencies(new_pop206))
print(compute_frequencies(new_pop207))
print(compute_frequencies(new_pop208))
print(compute_frequencies(new_pop209))
print(compute_frequencies(new_pop210))
print(compute_frequencies(new_pop211))
print(compute_frequencies(new_pop212))
print(compute_frequencies(new_pop213))
print(compute_frequencies(new_pop214))
print(compute_frequencies(new_pop215))
print(compute_frequencies(new_pop216))
print(compute_frequencies(new_pop217))
print(compute_frequencies(new_pop218))
print(compute_frequencies(new_pop219))
print(compute_frequencies(new_pop220))
print(compute_frequencies(new_pop221))
print(compute_frequencies(new_pop222))
print(compute_frequencies(new_pop223))
print(compute_frequencies(new_pop224))
print(compute_frequencies(new_pop225))
print(compute_frequencies(new_pop226))
print(compute_frequencies(new_pop227))
print(compute_frequencies(new_pop228))
print(compute_frequencies(new_pop229))
print(compute_frequencies(new_pop230))
print(compute_frequencies(new_pop231))
print(compute_frequencies(new_pop232))
print(compute_frequencies(new_pop233))
print(compute_frequencies(new_pop234))
print(compute_frequencies(new_pop235))
print(compute_frequencies(new_pop236))
print(compute_frequencies(new_pop237))
print(compute_frequencies(new_pop238))
print(compute_frequencies(new_pop239))
print(compute_frequencies(new_pop240))
print(compute_frequencies(new_pop241))
print(compute_frequencies(new_pop242))
print(compute_frequencies(new_pop243))
print(compute_frequencies(new_pop244))
print(compute_frequencies(new_pop245))
print(compute_frequencies(new_pop246))
print(compute_frequencies(new_pop247))
print(compute_frequencies(new_pop248))
print(compute_frequencies(new_pop249))
print(compute_frequencies(new_pop250))
print(compute_frequencies(new_pop251))
print(compute_frequencies(new_pop252))
print(compute_frequencies(new_pop253))
print(compute_frequencies(new_pop254))
print(compute_frequencies(new_pop255))
print(compute_frequencies(new_pop256))
print(compute_frequencies(new_pop257))
print(compute_frequencies(new_pop258))
print(compute_frequencies(new_pop259))
print(compute_frequencies(new_pop260))
print(compute_frequencies(new_pop261))
print(compute_frequencies(new_pop262))
print(compute_frequencies(new_pop263))
print(compute_frequencies(new_pop264))
print(compute_frequencies(new_pop265))
print(compute_frequencies(new_pop266))
print(compute_frequencies(new_pop267))
print(compute_frequencies(new_pop268))
print(compute_frequencies(new_pop269))
print(compute_frequencies(new_pop270))
print(compute_frequencies(new_pop271))
print(compute_frequencies(new_pop272))
print(compute_frequencies(new_pop273))
print(compute_frequencies(new_pop274))
print(compute_frequencies(new_pop275))
print(compute_frequencies(new_pop276))
print(compute_frequencies(new_pop277))
print(compute_frequencies(new_pop278))
print(compute_frequencies(new_pop279))
print(compute_frequencies(new_pop280))
print(compute_frequencies(new_pop281))
print(compute_frequencies(new_pop282))
print(compute_frequencies(new_pop283))
print(compute_frequencies(new_pop284))
print(compute_frequencies(new_pop285))
print(compute_frequencies(new_pop286))
print(compute_frequencies(new_pop287))
print(compute_frequencies(new_pop288))
print(compute_frequencies(new_pop289))
print(compute_frequencies(new_pop290))
print(compute_frequencies(new_pop291))
print(compute_frequencies(new_pop292))
print(compute_frequencies(new_pop293))
print(compute_frequencies(new_pop294))
print(compute_frequencies(new_pop295))
print(compute_frequencies(new_pop296))
print(compute_frequencies(new_pop297))
print(compute_frequencies(new_pop298))
print(compute_frequencies(new_pop299))
print(compute_frequencies(new_pop300))
print(compute_frequencies(new_pop301))
print(compute_frequencies(new_pop302))
print(compute_frequencies(new_pop303))
print(compute_frequencies(new_pop304))
print(compute_frequencies(new_pop305))
print(compute_frequencies(new_pop306))
print(compute_frequencies(new_pop307))
print(compute_frequencies(new_pop308))
print(compute_frequencies(new_pop309))
print(compute_frequencies(new_pop310))
print(compute_frequencies(new_pop311))
print(compute_frequencies(new_pop312))
print(compute_frequencies(new_pop313))
print(compute_frequencies(new_pop314))
print(compute_frequencies(new_pop315))
print(compute_frequencies(new_pop316))
print(compute_frequencies(new_pop317))
print(compute_frequencies(new_pop318))
print(compute_frequencies(new_pop319))
print(compute_frequencies(new_pop320))
print(compute_frequencies(new_pop321))
print(compute_frequencies(new_pop322))
print(compute_frequencies(new_pop323))
print(compute_frequencies(new_pop324))
print(compute_frequencies(new_pop325))
print(compute_frequencies(new_pop326))
print(compute_frequencies(new_pop327))
print(compute_frequencies(new_pop328))
print(compute_frequencies(new_pop329))
print(compute_frequencies(new_pop330))
print(compute_frequencies(new_pop331))
print(compute_frequencies(new_pop332))
print(compute_frequencies(new_pop333))
print(compute_frequencies(new_pop334))
print(compute_frequencies(new_pop335))
print(compute_frequencies(new_pop336))
print(compute_frequencies(new_pop337))
print(compute_frequencies(new_pop338))
print(compute_frequencies(new_pop339))
print(compute_frequencies(new_pop340))
print(compute_frequencies(new_pop341))
print(compute_frequencies(new_pop342))
print(compute_frequencies(new_pop343))
print(compute_frequencies(new_pop344))
print(compute_frequencies(new_pop345))
print(compute_frequencies(new_pop346))
print(compute_frequencies(new_pop347))
print(compute_frequencies(new_pop348))
print(compute_frequencies(new_pop349))
print(compute_frequencies(new_pop350))
print(compute_frequencies(new_pop351))
print(compute_frequencies(new_pop352))
print(compute_frequencies(new_pop353))
print(compute_frequencies(new_pop354))
print(compute_frequencies(new_pop355))
print(compute_frequencies(new_pop356))
print(compute_frequencies(new_pop357))
print(compute_frequencies(new_pop358))
print(compute_frequencies(new_pop359))
print(compute_frequencies(new_pop360))
print(compute_frequencies(new_pop361))
print(compute_frequencies(new_pop362))
print(compute_frequencies(new_pop363))
print(compute_frequencies(new_pop364))
print(compute_frequencies(new_pop365))
print(compute_frequencies(new_pop366))
print(compute_frequencies(new_pop367))
print(compute_frequencies(new_pop368))
print(compute_frequencies(new_pop369))
print(compute_frequencies(new_pop370))
print(compute_frequencies(new_pop371))
print(compute_frequencies(new_pop372))
print(compute_frequencies(new_pop373))
print(compute_frequencies(new_pop374))
print(compute_frequencies(new_pop375))
print(compute_frequencies(new_pop376))
print(compute_frequencies(new_pop377))
print(compute_frequencies(new_pop378))
print(compute_frequencies(new_pop379))
print(compute_frequencies(new_pop380))
print(compute_frequencies(new_pop381))
print(compute_frequencies(new_pop382))
print(compute_frequencies(new_pop383))
print(compute_frequencies(new_pop384))
print(compute_frequencies(new_pop385))
print(compute_frequencies(new_pop386))
print(compute_frequencies(new_pop387))
print(compute_frequencies(new_pop388))
print(compute_frequencies(new_pop389))
print(compute_frequencies(new_pop390))
print(compute_frequencies(new_pop391))
print(compute_frequencies(new_pop392))
print(compute_frequencies(new_pop393))
print(compute_frequencies(new_pop394))
print(compute_frequencies(new_pop395))
print(compute_frequencies(new_pop396))
print(compute_frequencies(new_pop397))
print(compute_frequencies(new_pop398))
print(compute_frequencies(new_pop399))
print(compute_frequencies(new_pop400))
print(compute_frequencies(new_pop401))
print(compute_frequencies(new_pop402))
print(compute_frequencies(new_pop403))
print(compute_frequencies(new_pop404))
print(compute_frequencies(new_pop405))
print(compute_frequencies(new_pop406))
print(compute_frequencies(new_pop407))
print(compute_frequencies(new_pop408))
print(compute_frequencies(new_pop409))
print(compute_frequencies(new_pop410))
print(compute_frequencies(new_pop411))
print(compute_frequencies(new_pop412))
print(compute_frequencies(new_pop413))
print(compute_frequencies(new_pop414))
print(compute_frequencies(new_pop415))
print(compute_frequencies(new_pop416))
print(compute_frequencies(new_pop417))
print(compute_frequencies(new_pop418))
print(compute_frequencies(new_pop419))
print(compute_frequencies(new_pop420))
print(compute_frequencies(new_pop421))
print(compute_frequencies(new_pop422))
print(compute_frequencies(new_pop423))
print(compute_frequencies(new_pop424))
print(compute_frequencies(new_pop425))
print(compute_frequencies(new_pop426))
print(compute_frequencies(new_pop427))
print(compute_frequencies(new_pop428))
print(compute_frequencies(new_pop429))
print(compute_frequencies(new_pop430))
print(compute_frequencies(new_pop431))
print(compute_frequencies(new_pop432))
print(compute_frequencies(new_pop433))
print(compute_frequencies(new_pop434))
print(compute_frequencies(new_pop435))
print(compute_frequencies(new_pop436))
print(compute_frequencies(new_pop437))
print(compute_frequencies(new_pop438))
print(compute_frequencies(new_pop439))
print(compute_frequencies(new_pop440))
print(compute_frequencies(new_pop441))
print(compute_frequencies(new_pop442))
print(compute_frequencies(new_pop443))
print(compute_frequencies(new_pop444))
print(compute_frequencies(new_pop445))
print(compute_frequencies(new_pop446))
print(compute_frequencies(new_pop447))
print(compute_frequencies(new_pop448))
print(compute_frequencies(new_pop449))
print(compute_frequencies(new_pop450))
print(compute_frequencies(new_pop451))
print(compute_frequencies(new_pop452))
print(compute_frequencies(new_pop453))
print(compute_frequencies(new_pop454))
print(compute_frequencies(new_pop455))
print(compute_frequencies(new_pop456))
print(compute_frequencies(new_pop457))
print(compute_frequencies(new_pop458))
print(compute_frequencies(new_pop459))
print(compute_frequencies(new_pop460))
print(compute_frequencies(new_pop461))
print(compute_frequencies(new_pop462))
print(compute_frequencies(new_pop463))
print(compute_frequencies(new_pop464))
print(compute_frequencies(new_pop465))
print(compute_frequencies(new_pop466))
print(compute_frequencies(new_pop467))
print(compute_frequencies(new_pop468))
print(compute_frequencies(new_pop469))
print(compute_frequencies(new_pop470))
print(compute_frequencies(new_pop471))
print(compute_frequencies(new_pop472))
print(compute_frequencies(new_pop473))
print(compute_frequencies(new_pop474))
print(compute_frequencies(new_pop475))
print(compute_frequencies(new_pop476))
print(compute_frequencies(new_pop477))
print(compute_frequencies(new_pop478))
print(compute_frequencies(new_pop479))
print(compute_frequencies(new_pop480))
print(compute_frequencies(new_pop481))
print(compute_frequencies(new_pop482))
print(compute_frequencies(new_pop483))
print(compute_frequencies(new_pop484))
print(compute_frequencies(new_pop485))
print(compute_frequencies(new_pop486))
print(compute_frequencies(new_pop487))
print(compute_frequencies(new_pop488))
print(compute_frequencies(new_pop489))
print(compute_frequencies(new_pop490))
print(compute_frequencies(new_pop491))
print(compute_frequencies(new_pop492))
print(compute_frequencies(new_pop493))
print(compute_frequencies(new_pop494))
print(compute_frequencies(new_pop495))
print(compute_frequencies(new_pop496))
print(compute_frequencies(new_pop497))
print(compute_frequencies(new_pop498))
print(compute_frequencies(new_pop499))
# Out:
# {'AA': 78, 'aa': 91, 'Aa': 300, 'aA': 31}
# {'AA': 79, 'aa': 90, 'Aa': 175, 'aA': 156}
# {'AA': 97, 'aa': 97, 'Aa': 145, 'aA': 161}
# {'AA': 84, 'aa': 73, 'Aa': 185, 'aA': 158}
# {'AA': 80, 'aa': 83, 'Aa': 165, 'aA': 172}
# {'AA': 69, 'aa': 83, 'Aa': 178, 'aA': 170}
# {'AA': 90, 'aa': 89, 'Aa': 155, 'aA': 166}
# {'AA': 92, 'aa': 82, 'Aa': 176, 'aA': 150}
# {'AA': 78, 'aa': 95, 'Aa': 155, 'aA': 172}
# {'AA': 82, 'aa': 72, 'Aa': 185, 'aA': 161}
# {'AA': 87, 'aa': 81, 'Aa': 173, 'aA': 159}
# {'AA': 95, 'aa': 95, 'Aa': 161, 'aA': 149}
# {'AA': 82, 'aa': 109, 'Aa': 156, 'aA': 153}
# {'AA': 88, 'aa': 104, 'Aa': 156, 'aA': 152}
# {'AA': 82, 'aa': 106, 'Aa': 155, 'aA': 157}
# {'AA': 80, 'aa': 87, 'Aa': 169, 'aA': 164}
# {'AA': 73, 'aa': 106, 'Aa': 137, 'aA': 184}
# {'AA': 84, 'aa': 88, 'Aa': 174, 'aA': 154}
# {'AA': 79, 'aa': 106, 'Aa': 149, 'aA': 166}
# {'AA': 75, 'aa': 94, 'Aa': 165, 'aA': 166}
# {'AA': 74, 'aa': 99, 'Aa': 144, 'aA': 183}
# {'AA': 91, 'aa': 87, 'Aa': 162, 'aA': 160}
# ...

# %%
#! bin/bash

def datos
        import scipy
   return losdatos
def build_population(N, p):
    """En esta fucion se crea la población que consta de N individus, cadaindiv>
    """
    population = []
    for i in range(N):
        allele1 = "A"
        if scipy.random.rand() > p:
            allele1 = "a"
        allele2 = "A"
        if scipy.random.rand() > p: #valores aleatorios de distribuicion normal
            allele2 = "a"
        population.append((allele1, allele2))
    return population

# %%
pops = compute_frequencies(my_pop)
new_pop = reproduce_population(my_pop)
  for i in (pops):
    for j in (new_pop):
    function = (i,j])
    print(function)
# Out:
#   File "<ipython-input-31-05ac9dfd395a>", line 4
#     for i in (pops):
#     ^
# IndentationError: unexpected indent

# %%
for i in range(10):
    print(i)
# Out:
#   File "<ipython-input-39-80b958ba4741>", line 1
#     for i in range(new 10):
#                         ^
# SyntaxError: invalid syntax

# %%
a = 1
while a < 10:
    print("¡Hola, mundo!")
    a = a + 1
# Out:
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!
# ¡Hola, mundo!

# %%
for i in [1, 2, 3]:
    print(f"Hola. Ahora i vale {i} y su cuadrado {i ** 2}")
# Out:
# Hola. Ahora i vale 1 y su cuadrado 1
# Hola. Ahora i vale 2 y su cuadrado 4
# Hola. Ahora i vale 3 y su cuadrado 9

# %%
print(compute_frequencies(my_pop))
numero = 0
while numero < 500:
    print(f"print(compute_frequencies(new_pop{numero}))")
    numero = numero + 1
# Out:
# {'AA': 78, 'aa': 91, 'Aa': 300, 'aA': 31}
# print(compute_frequencies(new_pop0))
# print(compute_frequencies(new_pop1))
# print(compute_frequencies(new_pop2))
# print(compute_frequencies(new_pop3))
# print(compute_frequencies(new_pop4))
# print(compute_frequencies(new_pop5))
# print(compute_frequencies(new_pop6))
# print(compute_frequencies(new_pop7))
# print(compute_frequencies(new_pop8))
# print(compute_frequencies(new_pop9))
# print(compute_frequencies(new_pop10))
# print(compute_frequencies(new_pop11))
# print(compute_frequencies(new_pop12))
# print(compute_frequencies(new_pop13))
# print(compute_frequencies(new_pop14))
# print(compute_frequencies(new_pop15))
# print(compute_frequencies(new_pop16))
# print(compute_frequencies(new_pop17))
# print(compute_frequencies(new_pop18))
# print(compute_frequencies(new_pop19))
# print(compute_frequencies(new_pop20))
# print(compute_frequencies(new_pop21))
# print(compute_frequencies(new_pop22))
# print(compute_frequencies(new_pop23))
# ...
