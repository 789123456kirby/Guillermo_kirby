# %% [markdown]
# <a href="https://colab.research.google.com/github/789123456kirby/Guillermo_kirby/blob/main/poblaciones_mendelianas_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# T6_Poblaciones
#
# 1.   Crear el modulo que se llame poblacionmendeliana
# 2.   Guardar las 3 funciones de: i) generacion de la poblacion, ii) conteo de frecuencia de alelos y iii) reproduccion de la poblacion en el modulo del poblacionmendeliana.
# 3.   Generar una explicación para cada función.
# 4.   Generar las poblaciones 500 generaciones.
# 5.   Calcular las proporciones de AA, Aa, aA, aa de todas las generaciones
# Generar el repositorio tarea6 con un readme.

# %%
from google.colab import drive #se accede a drive

drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os 
os.chdir("gdrive/My Drive/tarea_6") #se accede a la carpeta "tarea_6" en donde estan las funciones

# %%
ls #se verifica que los elementos esten dentro de la carpepa
# Out:
# 'poblaciones_mendelianas .pynb'   poblacionmendeliana.py   __pycache__/

# %%
import poblacionmendeliana #se importa el arcibo prebiamente creado en e guit bash

# %%
fr = [poblacionmendeliana.creacion_alelos(x, 0.40) for x in range(0, 500)] #se llena los requisitos para la funcion uno ya que las fucniones dos y tres son dependientes de esta 
nuevas = [poblacionmendeliana.reproduce_population(i) for i in fr]
nuevas2 = [poblacionmendeliana.compute_frequencies(u) for u in nuevas]
nuevas2
# Out:
# [{'AA': 0, 'Aa': 0, 'aA': 0, 'aa': 0},
#  {'AA': 0, 'Aa': 1, 'aA': 0, 'aa': 0},
#  {'AA': 0, 'Aa': 0, 'aA': 0, 'aa': 2},
#  {'AA': 0, 'Aa': 1, 'aA': 1, 'aa': 1},
#  {'AA': 1, 'Aa': 0, 'aA': 0, 'aa': 3},
#  {'AA': 0, 'Aa': 1, 'aA': 1, 'aa': 3},
#  {'AA': 5, 'Aa': 1, 'aA': 0, 'aa': 0},
#  {'AA': 2, 'Aa': 1, 'aA': 2, 'aa': 2},
#  {'AA': 1, 'Aa': 0, 'aA': 3, 'aa': 4},
#  {'AA': 2, 'Aa': 2, 'aA': 3, 'aa': 2},
#  {'AA': 0, 'Aa': 5, 'aA': 2, 'aa': 3},
#  {'AA': 0, 'Aa': 4, 'aA': 1, 'aa': 6},
#  {'AA': 3, 'Aa': 1, 'aA': 5, 'aa': 3},
#  {'AA': 0, 'Aa': 4, 'aA': 5, 'aa': 4},
#  {'AA': 2, 'Aa': 6, 'aA': 5, 'aa': 1},
#  {'AA': 0, 'Aa': 6, 'aA': 1, 'aa': 8},
#  {'AA': 2, 'Aa': 2, 'aA': 2, 'aa': 10},
#  {'AA': 3, 'Aa': 3, 'aA': 2, 'aa': 9},
#  {'AA': 4, 'Aa': 4, 'aA': 5, 'aa': 5},
#  {'AA': 4, 'Aa': 3, 'aA': 6, 'aa': 6},
#  {'AA': 4, 'Aa': 4, 'aA': 8, 'aa': 4},
#  {'AA': 3, 'Aa': 7, 'aA': 4, 'aa': 7},
#  {'AA': 4, 'Aa': 2, 'aA': 6, 'aa': 10},
#  {'AA': 7, 'Aa': 3, 'aA': 4, 'aa': 9},
# ...
